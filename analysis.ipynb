# %%
from reward import RewardTracker

reward_path: str = 'C:/Users/jerem/Pokemon Blue DQN/analysis/reward.json'

# %%
tracker = RewardTracker(reward_path)

# %%
tracker.plot_episode_results()
